-- %%
-- ===== Create catalog if not exists
CREATE CATALOG IF NOT EXISTS fflogs_graphql;

-- ===== Create schemas if not exists
CREATE SCHEMA IF NOT EXISTS fflogs_graphql.bronze;
CREATE SCHEMA IF NOT EXISTS fflogs_graphql.silver;
CREATE SCHEMA IF NOT EXISTS fflogs_graphql.gold;

-- ===== Create volume if not exists
CREATE VOLUME IF NOT EXISTS fflogs_graphql.bronze.encounter_ranking;
